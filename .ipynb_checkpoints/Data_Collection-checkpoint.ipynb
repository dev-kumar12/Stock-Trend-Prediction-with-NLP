# %%
import yfinance as yf
import pandas as pd

# Define the stock and the time period
ticker_symbol = "RELIANCE.NS"
start_date = "2020-01-01"
end_date = "2025-08-27" # Using today's date as the end

try:
    print(f"Downloading 5 years of stock data for {ticker_symbol}...")
    stock_df = yf.download(ticker_symbol, start=start_date, end=end_date)

    if not stock_df.empty:
        file_path = "reliance_stock_data_5_years.csv"
        stock_df.to_csv(file_path)
        print(f"✅ Success! Data downloaded and saved to '{file_path}'")
        print(f"Data shape: {stock_df.shape}")
        display(stock_df.tail())
    else:
        print("❌ Download failed. The returned data was empty.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Downloading 5 years of stock data for RELIANCE.NS...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# ✅ Success! Data downloaded and saved to 'reliance_stock_data_5_years.csv'
# Data shape: (1401, 5)
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2025-08-20  1413.000000  1424.900024  1410.000000  1413.000000     8725641
# 2025-08-21  1424.800049  1431.900024  1420.300049  1425.000000    11021323
# 2025-08-22  1409.199951  1423.400024  1407.900024  1420.000000     5818868
# 2025-08-25  1412.599976  1419.500000  1405.699951  1414.699951     5979407
# 2025-08-26  1384.900024  1410.000000  1381.599976  1408.000000    12145259

# %%
# !pip install gnews
# Out:
# Collecting gnews
#   Downloading gnews-0.4.2-py3-none-any.whl.metadata (19 kB)
# Collecting feedparser~=6.0.2 (from gnews)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: beautifulsoup4<5,>=4.9.3 in c:\users\devgo\.conda\envs\capstone_env\lib\site-packages (from gnews) (4.13.4)
# Collecting dnspython (from gnews)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: requests in c:\users\devgo\.conda\envs\capstone_env\lib\site-packages (from gnews) (2.32.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\devgo\.conda\envs\capstone_env\lib\site-packages (from beautifulsoup4<5,>=4.9.3->gnews) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\devgo\.conda\envs\capstone_env\lib\site-packages (from beautifulsoup4<5,>=4.9.3->gnews) (4.14.1)
# Collecting sgmllib3k (from feedparser~=6.0.2->gnews)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\devgo\.conda\envs\capstone_env\lib\site-packages (from requests->gnews) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devgo\.conda\envs\capstone_env\lib\site-packages (from requests->gnews) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devgo\.conda\envs\capstone_env\lib\site-packages (from requests->gnews) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devgo\.conda\envs\capstone_env\lib\site-packages (from requests->gnews) (2025.8.3)
# Downloading gnews-0.4.2-py3-none-any.whl (18 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py): started
#   Building wheel for sgmllib3k (setup.py): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6105 sha256=3eafb56b6583136115ca7248bc76b0e42188d5eafedd4a847072f9e28d98fd63
#   Stored in directory: c:\users\devgo\appdata\local\pip\cache\wheels\65\7a\a7\78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser, dnspython, gnews
#
#    ---------- ----------------------------- 1/4 [feedparser]
#    -------------------- ------------------- 2/4 [dnspython]
#    -------------------- ------------------- 2/4 [dnspython]
#    -------------------- ------------------- 2/4 [dnspython]
#    -------------------- ------------------- 2/4 [dnspython]
#    -------------------- ------------------- 2/4 [dnspython]
#    -------------------- ------------------- 2/4 [dnspython]
#    ------------------------------ --------- 3/4 [gnews]
#    ---------------------------------------- 4/4 [gnews]
#
# Successfully installed dnspython-2.7.0 feedparser-6.0.11 gnews-0.4.2 sgmllib3k-1.0.0
#   DEPRECATION: Building 'sgmllib3k' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'sgmllib3k'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
import pandas as pd
from gnews import GNews
import time
from datetime import datetime

# This list will store all the articles we find
all_news = []
start_year = 2020
end_year = datetime.now().year

print(f"Starting deep news search from {start_year} to {end_year}. This will take a long time...")

# Loop through each year and each month
for year in range(start_year, end_year + 1):
    for month in range(1, 13):
        # Stop if we are in the future
        if year == end_year and month > datetime.now().month:
            break
            
        print(f"Fetching news for month: {year}-{month:02d}...")
        
        # Define the start and end date for the current month
        start_date = (year, month, 1)
        if month == 12:
            end_date = (year + 1, 1, 1)
        else:
            end_date = (year, month + 1, 1)
            
        # Initialize GNews for this specific time period
        google_news = GNews(language='en', country='IN', start_date=start_date, end_date=end_date)
        
        # Get the news and add it to our master list
        monthly_news = google_news.get_news('Reliance Industries')
        if monthly_news:
            all_news.extend(monthly_news)
        
        # Be polite to the server and wait 1 second between requests
        time.sleep(1)

# --- Process the final, large dataset ---
if all_news:
    news_df = pd.DataFrame(all_news)
    
    # Clean up and save the data
    news_df = news_df[['published date', 'title', 'publisher']]
    news_df.rename(columns={'published date': 'date', 'publisher': 'source'}, inplace=True)
    
    file_path = "reliance_news_data_FULL.csv"
    news_df.to_csv(file_path, index=False)
    
    print(f"\n✅ FULL news download complete! Data saved to '{file_path}'")
    print(f"Total articles found: {len(news_df)}")
    display(news_df.head())
else:
    print("❌ No articles were found with the deep search.")
# Out:
# Starting deep news search from 2020 to 2025. This will take a long time...
# Fetching news for month: 2020-01...
# Fetching news for month: 2020-02...
# Fetching news for month: 2020-03...
# Fetching news for month: 2020-04...
# Fetching news for month: 2020-05...
# Fetching news for month: 2020-06...
# Fetching news for month: 2020-07...
# Fetching news for month: 2020-08...
# Fetching news for month: 2020-09...
# Fetching news for month: 2020-10...
# Fetching news for month: 2020-11...
# Fetching news for month: 2020-12...
# Fetching news for month: 2021-01...
# Fetching news for month: 2021-02...
# Fetching news for month: 2021-03...
# Fetching news for month: 2021-04...
# Fetching news for month: 2021-05...
# Fetching news for month: 2021-06...
# Fetching news for month: 2021-07...
# Fetching news for month: 2021-08...
# Fetching news for month: 2021-09...
# Fetching news for month: 2021-10...
# Fetching news for month: 2021-11...
# Fetching news for month: 2021-12...
# Fetching news for month: 2022-01...
# Fetching news for month: 2022-02...
# Fetching news for month: 2022-03...
# Fetching news for month: 2022-04...
# Fetching news for month: 2022-05...
# Fetching news for month: 2022-06...
# Fetching news for month: 2022-07...
# Fetching news for month: 2022-08...
# Fetching news for month: 2022-09...
# Fetching news for month: 2022-10...
# Fetching news for month: 2022-11...
# Fetching news for month: 2022-12...
# Fetching news for month: 2023-01...
# Fetching news for month: 2023-02...
# Fetching news for month: 2023-03...
# Fetching news for month: 2023-04...
# Fetching news for month: 2023-05...
# Fetching news for month: 2023-06...
# Fetching news for month: 2023-07...
# Fetching news for month: 2023-08...
# Fetching news for month: 2023-09...
# Fetching news for month: 2023-10...
# Fetching news for month: 2023-11...
# Fetching news for month: 2023-12...
# Fetching news for month: 2024-01...
# Fetching news for month: 2024-02...
# Fetching news for month: 2024-03...
# Fetching news for month: 2024-04...
# Fetching news for month: 2024-05...
# Fetching news for month: 2024-06...
# Fetching news for month: 2024-07...
# Fetching news for month: 2024-08...
# Fetching news for month: 2024-09...
# Fetching news for month: 2024-10...
# Fetching news for month: 2024-11...
# Fetching news for month: 2024-12...
# Fetching news for month: 2025-01...
# Fetching news for month: 2025-02...
# Fetching news for month: 2025-03...
# Fetching news for month: 2025-04...
# Fetching news for month: 2025-05...
# Fetching news for month: 2025-06...
# Fetching news for month: 2025-07...
# Fetching news for month: 2025-08...
#
# ✅ FULL news download complete! Data saved to 'reliance_news_data_FULL.csv'
# Total articles found: 6250
#                             date  \
# 0  Tue, 21 Jan 2020 08:00:00 GMT
# 1  Fri, 17 Jan 2020 08:00:00 GMT
# 2  Mon, 06 Jan 2020 08:00:00 GMT
# 3  Thu, 02 Jan 2020 08:00:00 GMT
# 4  Tue, 07 Jan 2020 08:00:00 GMT
#
#                                                title  \
# 0  Mukesh Ambani's Reliance Industries is India's...
# 1  Reliance Industries posts record Q3 profit at ...
# 2  Is 2020 The Year That Reliance Becomes India's...
# 3  Mukesh Ambani: Asia's richest man takes on ret...
# 4  Reliance refers to start-up playbook to grow J...
#
#                                               source
# 0  {'href': 'https://www.livemint.com', 'title': ...
# 1  {'href': 'https://www.businesstoday.in', 'titl...
# 2  {'href': 'https://variety.com', 'title': 'Vari...
# 3    {'href': 'https://www.bbc.com', 'title': 'BBC'}
# 4  {'href': 'https://www.business-standard.com', ...

# %%
# !pip install pandas_ta
# Out:
# Requirement already satisfied: pandas_ta in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (0.3.14b0)
# Requirement already satisfied: pandas in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from pandas_ta) (2.3.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from pandas->pandas_ta) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from pandas->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from pandas->pandas_ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from pandas->pandas_ta) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.17.0)

# %%
# !pip install --upgrade pandas_ta
# Out:
# Requirement already satisfied: pandas_ta in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (0.3.14b0)
# Requirement already satisfied: pandas in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from pandas_ta) (2.3.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from pandas->pandas_ta) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from pandas->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from pandas->pandas_ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from pandas->pandas_ta) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\devgo\.conda\envs\capstone_v2\lib\site-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.17.0)

# %%
import pandas as pd
import pandas_ta as ta

file_path = "reliance_stock_data_5_years.csv"

# --- THE FIX ---
# This tells pandas to use the first column as the index
# AND to skip the two junk rows (row 1 and 2 from your screenshot) right after the header.
stock_df = pd.read_csv(
    file_path,
    index_col=0,
    parse_dates=True,
    skiprows=[1, 2] # This is the key fix
)

# We will then correctly name the index 'Date' for future use
stock_df.index.name = 'Date'

# Calculate the 14-period SMA and RSI using pandas_ta
stock_df.ta.sma(length=14, append=True)
stock_df.ta.rsi(length=14, append=True)

# Remove the first few rows that have missing indicator values
stock_df.dropna(inplace=True)

print("✅ Technical indicators (SMA_14 and RSI_14) have been calculated and added.")
display(stock_df.head())
# Out:
# ✅ Technical indicators (SMA_14 and RSI_14) have been calculated and added.
#                  Close        High         Low        Open    Volume  \
# Date
# 2020-01-23  683.041199  689.796218  680.289966  687.358123  11247739
# 2020-01-24  680.670044  687.290859  679.327963  683.108078  14628445
# 2020-01-27  673.959839  681.967470  673.266431  677.695280  13387750
# 2020-01-28  658.391907  675.503182  654.745994  674.876846  24532236
# 2020-01-29  662.015503  668.524454  654.947287  659.420810  24746565
#
#                 SMA_14     RSI_14
# Date
# 2020-01-23  686.278006  46.666189
# 2020-01-24  686.918675  44.935979
# 2020-01-27  686.341910  40.373948
# 2020-01-28  685.019021  32.204985
# 2020-01-29  682.841370  35.477419

# %%
import pandas as pd

file_path = "reliance_stock_data_5_years.csv"

print("Starting the one-time fix for the stock data CSV file...")

try:
    # Step 1: Load the messy CSV file using our robust command
    clean_df = pd.read_csv(
        file_path,
        index_col=0,
        parse_dates=True,
        skiprows=[1, 2]
    )
    clean_df.index.name = 'Date'
    print(" -> Successfully loaded the messy data into memory.")

    # Step 2: Save the clean DataFrame back to the SAME file path
    # This will OVERWRITE the old, messy file with a clean one.
    clean_df.to_csv(file_path)
    print(f" -> Successfully saved a clean version back to '{file_path}'.")

    print("\n✅✅✅ PERMANENT FIX COMPLETE ✅✅✅")
    print("The stock data CSV file is now permanently fixed. You will not see this error again.")

except Exception as e:
    print(f"An error occurred during the fix: {e}")
# Out:
# Starting the one-time fix for the stock data CSV file...
#  -> Successfully loaded the messy data into memory.
#  -> Successfully saved a clean version back to 'reliance_stock_data_5_years.csv'.
#
# ✅✅✅ PERMANENT FIX COMPLETE ✅✅✅
# The stock data CSV file is now permanently fixed. You will not see this error again.

# %%
# !conda install -c conda-forge nltk -y
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# --- NLTK Setup ---
# This directly downloads the required resources.
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# --------------------

# Initialize the tools
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_text(text):
    """
    Cleans a text string by making it lowercase, removing punctuation,
    numbers, stopwords, and then lemmatizing the words.
    """
    if not isinstance(text, str):
        return ""
        
    text = re.sub(r'[^a-zA-Z\s]', '', text, re.I|re.A)
    words = text.lower().split()
    cleaned_words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    
    return " ".join(cleaned_words)

print("✅ The clean_text function is now ready to use.")
# Out:
# ✅ The clean_text function is now ready to use.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\devGo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\devGo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\devGo\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
import pandas as pd

# Load the full news dataset from the CSV file
file_path = "reliance_news_data_FULL.csv"
news_df = pd.read_csv(file_path)

# Apply our cleaning function to the 'title' column
print("Cleaning all news headlines... this may take a minute.")
news_df['cleaned_title'] = news_df['title'].apply(clean_text)
print("✅ Text cleaning complete.")

# Display the original and cleaned titles to see the result
display(news_df[['title', 'cleaned_title']].head())
# Out:
# Cleaning all news headlines... this may take a minute.
# ✅ Text cleaning complete.
#                                                title  \
# 0  Mukesh Ambani's Reliance Industries is India's...
# 1  Reliance Industries posts record Q3 profit at ...
# 2  Is 2020 The Year That Reliance Becomes India's...
# 3  Mukesh Ambani: Asia's richest man takes on ret...
# 4  Reliance refers to start-up playbook to grow J...
#
#                                        cleaned_title
# 0  mukesh ambanis reliance industry india answer ...
# 1  reliance industry post record q profit r crore...
# 2  year reliance becomes india digital champion v...
# 3  mukesh ambani asia richest man take retail gia...
# 4  reliance refers startup playbook grow jio inte...

# %%
import os
import shutil
from pathlib import Path

# Define the cache directory
cache_dir = Path.home() / ".cache" / "huggingface"

try:
    if os.path.exists(cache_dir):
        print(f"Found cache directory at: {cache_dir}")
        shutil.rmtree(cache_dir)
        print("✅ Hugging Face cache has been cleared successfully.")
    else:
        print("Cache directory not found, no action needed.")

except Exception as e:
    print(f"An error occurred while clearing the cache: {e}")
# Out:
# Found cache directory at: C:\Users\devGo\.cache\huggingface
# ✅ Hugging Face cache has been cleared successfully.

# %%
import pandas as pd
import torch
# --- CHANGE 1: Import the specific BERT model class ---
from transformers import AutoTokenizer, BertForSequenceClassification

# --- 1. Load the FinBERT Model and Tokenizer ---
print("Loading FinBERT model and tokenizer...")
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
# --- CHANGE 2: Use the specific class to load the model ---
model = BertForSequenceClassification.from_pretrained("ProsusAI/finbert")
print("✅ Model and tokenizer loaded.")

# --- 2. Load Your Cleaned News Data ---
file_path = "reliance_news_data_FULL.csv"
news_df = pd.read_csv(file_path)
news_df.dropna(subset=['title'], inplace=True)
news_df['cleaned_title'] = news_df['title'].apply(clean_text)

# --- 3. Define a Function for Batch Sentiment Analysis ---
def get_finbert_sentiments(text_list):
    inputs = tokenizer(text_list, padding=True, truncation=True, return_tensors="pt", max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
    sentiment_labels = [model.config.id2label[label_id] for label_id in torch.argmax(predictions, dim=1).tolist()]
    return sentiment_labels

# --- 4. Process the Headlines in Batches ---
print("\nStarting sentiment analysis with FinBERT. This will take a very long time...")
batch_size = 64
all_sentiments = []
titles_to_process = news_df['cleaned_title'].tolist()

for i in range(0, len(titles_to_process), batch_size):
    batch = titles_to_process[i:i + batch_size]
    sentiments = get_finbert_sentiments(batch)
    all_sentiments.extend(sentiments)
    print(f"  Processed {min(i + batch_size, len(titles_to_process))}/{len(titles_to_process)} headlines...")

# --- 5. Add Sentiments to DataFrame ---
news_df['finbert_sentiment'] = all_sentiments
print("\n✅ FinBERT sentiment analysis complete.")
display(news_df[['cleaned_title', 'finbert_sentiment']].head())

# Save the results to a new CSV
news_df.to_csv("reliance_news_with_finbert_sentiment.csv", index=False)
print("✅ Results have been saved to 'reliance_news_with_finbert_sentiment.csv'")
# Out:
# Loading FinBERT model and tokenizer...
# ✅ Model and tokenizer loaded.
#
# Starting sentiment analysis with FinBERT. This will take a very long time...
#   Processed 64/6250 headlines...
#   Processed 128/6250 headlines...
#   Processed 192/6250 headlines...
#   Processed 256/6250 headlines...
#   Processed 320/6250 headlines...
#   Processed 384/6250 headlines...
#   Processed 448/6250 headlines...
#   Processed 512/6250 headlines...
#   Processed 576/6250 headlines...
#   Processed 640/6250 headlines...
#   Processed 704/6250 headlines...
#   Processed 768/6250 headlines...
#   Processed 832/6250 headlines...
#   Processed 896/6250 headlines...
#   Processed 960/6250 headlines...
#   Processed 1024/6250 headlines...
#   Processed 1088/6250 headlines...
#   Processed 1152/6250 headlines...
#   Processed 1216/6250 headlines...
#   Processed 1280/6250 headlines...
#   Processed 1344/6250 headlines...
#   Processed 1408/6250 headlines...
#   Processed 1472/6250 headlines...
#   Processed 1536/6250 headlines...
#   Processed 1600/6250 headlines...
#   Processed 1664/6250 headlines...
#   Processed 1728/6250 headlines...
#   Processed 1792/6250 headlines...
#   Processed 1856/6250 headlines...
#   Processed 1920/6250 headlines...
#   Processed 1984/6250 headlines...
#   Processed 2048/6250 headlines...
#   Processed 2112/6250 headlines...
#   Processed 2176/6250 headlines...
#   Processed 2240/6250 headlines...
#   Processed 2304/6250 headlines...
#   Processed 2368/6250 headlines...
#   Processed 2432/6250 headlines...
#   Processed 2496/6250 headlines...
#   Processed 2560/6250 headlines...
#   Processed 2624/6250 headlines...
#   Processed 2688/6250 headlines...
#   Processed 2752/6250 headlines...
#   Processed 2816/6250 headlines...
#   Processed 2880/6250 headlines...
#   Processed 2944/6250 headlines...
#   Processed 3008/6250 headlines...
#   Processed 3072/6250 headlines...
#   Processed 3136/6250 headlines...
#   Processed 3200/6250 headlines...
#   Processed 3264/6250 headlines...
#   Processed 3328/6250 headlines...
#   Processed 3392/6250 headlines...
#   Processed 3456/6250 headlines...
#   Processed 3520/6250 headlines...
#   Processed 3584/6250 headlines...
#   Processed 3648/6250 headlines...
#   Processed 3712/6250 headlines...
#   Processed 3776/6250 headlines...
#   Processed 3840/6250 headlines...
#   Processed 3904/6250 headlines...
#   Processed 3968/6250 headlines...
#   Processed 4032/6250 headlines...
#   Processed 4096/6250 headlines...
#   Processed 4160/6250 headlines...
#   Processed 4224/6250 headlines...
#   Processed 4288/6250 headlines...
#   Processed 4352/6250 headlines...
#   Processed 4416/6250 headlines...
#   Processed 4480/6250 headlines...
#   Processed 4544/6250 headlines...
#   Processed 4608/6250 headlines...
#   Processed 4672/6250 headlines...
#   Processed 4736/6250 headlines...
#   Processed 4800/6250 headlines...
#   Processed 4864/6250 headlines...
#   Processed 4928/6250 headlines...
#   Processed 4992/6250 headlines...
#   Processed 5056/6250 headlines...
#   Processed 5120/6250 headlines...
#   Processed 5184/6250 headlines...
#   Processed 5248/6250 headlines...
#   Processed 5312/6250 headlines...
#   Processed 5376/6250 headlines...
#   Processed 5440/6250 headlines...
#   Processed 5504/6250 headlines...
#   Processed 5568/6250 headlines...
#   Processed 5632/6250 headlines...
#   Processed 5696/6250 headlines...
#   Processed 5760/6250 headlines...
#   Processed 5824/6250 headlines...
#   Processed 5888/6250 headlines...
#   Processed 5952/6250 headlines...
#   Processed 6016/6250 headlines...
#   Processed 6080/6250 headlines...
#   Processed 6144/6250 headlines...
#   Processed 6208/6250 headlines...
#   Processed 6250/6250 headlines...
#
# ✅ FinBERT sentiment analysis complete.
#                                        cleaned_title finbert_sentiment
# 0  mukesh ambanis reliance industry india answer ...           neutral
# 1  reliance industry post record q profit r crore...          positive
# 2  year reliance becomes india digital champion v...           neutral
# 3  mukesh ambani asia richest man take retail gia...           neutral
# 4  reliance refers startup playbook grow jio inte...           neutral
# ✅ Results have been saved to 'reliance_news_with_finbert_sentiment.csv'

# %%
# !conda install numpy=1.23.5 -y
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\devGo\.conda\envs\capstone_v2
#
#   added / updated specs:
#     - numpy=1.23.5
#
#
# The following packages will be DOWNGRADED:
#
#   numpy                                2.0.1-py39h055cbcc_1 --> 1.23.5-py39h6917f2d_1
#   numpy-base                           2.0.1-py39h65a83cf_1 --> 1.23.5-py39h46c4fa8_1
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import pandas as pd
import numpy as np

# --- 1. Load Your Two Processed Datasets ---
# --- THE FIX IS HERE ---
# Load stock_df using the first column as the index to avoid the 'Date' not found error.
stock_df = pd.read_csv("reliance_stock_data_5_years.csv", index_col=0, parse_dates=True)
news_df = pd.read_csv("reliance_news_with_finbert_sentiment.csv")

# --- 2. Process the Stock Data (Add Indicators Again) ---
import pandas_ta as ta
stock_df.ta.sma(length=14, append=True)
stock_df.ta.rsi(length=14, append=True)
stock_df.dropna(inplace=True)


# --- 3. Process the News Data ---
sentiment_map = {'positive': 1, 'neutral': 0, 'negative': -1}
news_df['sentiment_score'] = news_df['finbert_sentiment'].map(sentiment_map)
news_df['date'] = pd.to_datetime(news_df['date'])
news_df['just_date'] = news_df['date'].dt.date
daily_sentiment = news_df.groupby('just_date')['sentiment_score'].mean().reset_index()
daily_sentiment['just_date'] = pd.to_datetime(daily_sentiment['just_date'])


# --- 4. Merge the Datasets ---
final_df = stock_df.merge(daily_sentiment, left_index=True, right_on='just_date', how='left')
final_df['sentiment_score'].fillna(method='ffill', inplace=True)
final_df.dropna(inplace=True)
final_df.set_index('just_date', inplace=True)
final_df.index.name = 'Date'


print("✅✅✅ Final master dataset created successfully!")
display(final_df.head())
# Out:
# ✅✅✅ Final master dataset created successfully!
# C:\Users\devGo\AppData\Local\Temp\ipykernel_21236\920356968.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_df['sentiment_score'].fillna(method='ffill', inplace=True)
# C:\Users\devGo\AppData\Local\Temp\ipykernel_21236\920356968.py:28: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   final_df['sentiment_score'].fillna(method='ffill', inplace=True)
#                  Close        High         Low        Open    Volume  \
# Date
# 2020-01-21  686.194946  691.540813  680.871417  683.823983  18922720
# 2020-01-22  685.948853  691.943392  684.942307  690.713176  10322817
# 2020-01-23  683.041199  689.796218  680.289966  687.358123  11247739
# 2020-01-24  680.670044  687.290859  679.327963  683.108078  14628445
# 2020-01-27  673.959839  681.967470  673.266431  677.695280  13387750
#
#                 SMA_14     RSI_14  sentiment_score
# Date
# 2020-01-21  686.669434  52.074288              0.0
# 2020-01-22  686.607121  51.897962              0.0
# 2020-01-23  686.278006  49.754337              0.0
# 2020-01-24  686.918675  48.012704              0.0
# 2020-01-27  686.341910  43.384418              0.0

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Create a new DataFrame with only the features we'll use for modeling
# We are dropping columns like Open, High, Low as they are highly correlated with Close
model_df = final_df[['Close', 'Volume', 'SMA_14', 'RSI_14', 'sentiment_score']]

# Initialize the scaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit and transform the data
scaled_data = scaler.fit_transform(model_df)

# Create a new DataFrame with the scaled data
scaled_df = pd.DataFrame(scaled_data, columns=model_df.columns, index=model_df.index)

print("✅ Data has been successfully scaled.")
display(scaled_df.head())
# Out:
# ✅ Data has been successfully scaled.
#                Close    Volume    SMA_14    RSI_14  sentiment_score
# Date
# 2020-01-21  0.243548  0.132620  0.207626  0.537352              0.5
# 2020-01-22  0.243342  0.072348  0.207570  0.534684              0.5
# 2020-01-23  0.240906  0.078830  0.207273  0.502246              0.5
# 2020-01-24  0.238919  0.102524  0.207850  0.475891              0.5
# 2020-01-27  0.233298  0.093828  0.207331  0.405855              0.5

# %%
import numpy as np

# --- Create sequences ---
# We'll look at 60 days of history to predict the 61st day
time_step = 60
X_data, y_data = [], []

# Loop through the scaled data to create the sequences
for i in range(time_step, len(scaled_df)):
    # X_data will contain a window of the previous 60 days
    X_data.append(scaled_df.iloc[i-time_step:i].values)
    # y_data will contain the closing price of the 61st day
    # .iloc[i, 0] gets the 'Close' price, which is the first column
    y_data.append(scaled_df.iloc[i, 0])

# Convert the lists to numpy arrays
X_data, y_data = np.array(X_data), np.array(y_data)

print("✅ Data has been successfully converted into sequences.")
print(f"Shape of X_data: {X_data.shape}")
print(f"Shape of y_data: {y_data.shape}")
# Out:
# ✅ Data has been successfully converted into sequences.
# Shape of X_data: (1327, 60, 5)
# Shape of y_data: (1327,)

# %%
# Define the split point (80% of the data for training)
train_size = int(len(X_data) * 0.8)

# Split the data chronologically
X_train, X_test = X_data[:train_size], X_data[train_size:]
y_train, y_test = y_data[:train_size], y_data[train_size:]

print("✅ Data has been successfully split into training and testing sets.")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# ✅ Data has been successfully split into training and testing sets.
# X_train shape: (1061, 60, 5)
# y_train shape: (1061,)
# X_test shape: (266, 60, 5)
# y_test shape: (266,)

# %%
# !conda install tensorflow -y
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\devGo\.conda\envs\capstone_v2
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _tflow_select-2.3.0        |              mkl           3 KB
#     abseil-cpp-20211102.0      |       hd77b12b_0         1.7 MB
#     absl-py-2.1.0              |   py39haa95532_0         191 KB
#     aiohappyeyeballs-2.6.1     |   py39haa95532_0          33 KB
#     aiohttp-3.11.10            |   py39h827c3e9_0         779 KB
#     aiosignal-1.4.0            |   py39haa95532_0          17 KB
#     astunparse-1.6.3           |             py_0          17 KB
#     async-timeout-5.0.1        |   py39haa95532_0          14 KB
#     c-ares-1.34.5              |       h731ff69_0         217 KB
#     cachetools-5.5.1           |   py39haa95532_0          30 KB
#     cryptography-41.0.3        |   py39h3438e0d_0         1.1 MB
#     flatbuffers-25.2.10        |       hbdc3ed3_0         2.0 MB
#     frozenlist-1.5.0           |   py39h827c3e9_0          61 KB
#     gast-0.4.0                 |     pyhd3eb1b0_0          13 KB
#     giflib-5.2.2               |       h7edc060_0         105 KB
#     google-auth-2.38.0         |   py39haa95532_1         315 KB
#     google-auth-oauthlib-0.4.4 |     pyhd3eb1b0_0          18 KB
#     google-pasta-0.2.0         |     pyhd3eb1b0_0          46 KB
#     grpc-cpp-1.48.2            |       hf108199_0        23.5 MB
#     grpcio-1.48.2              |   py39hf108199_0         2.0 MB
#     h5py-3.12.1                |   py39h535c9fb_1         1.1 MB
#     hdf5-1.14.5                |       ha36df97_2         2.1 MB
#     icu-58.2                   |       ha925a31_3         9.4 MB
#     keras-2.10.0               |   py39haa95532_0         1.5 MB
#     keras-preprocessing-1.1.2  |     pyhd3eb1b0_0          35 KB
#     krb5-1.21.3                |       h885b0b7_4         145 KB
#     libcurl-8.14.1             |       ha9f67de_0         402 KB
#     libprotobuf-3.20.3         |       h23ce68f_0         2.2 MB
#     libssh2-1.10.0             |       hcd4344a_2         236 KB
#     markdown-3.8               |   py39haa95532_0         178 KB
#     multidict-6.1.0            |   py39h827c3e9_0          59 KB
#     oauthlib-3.3.1             |   py39haa95532_0         225 KB
#     openssl-1.1.1w             |       h2bbff1b_0         5.5 MB
#     opt_einsum-3.3.0           |     pyhd3eb1b0_1          57 KB
#     propcache-0.3.1            |   py39h827c3e9_0          61 KB
#     protobuf-3.20.3            |   py39hd77b12b_0         232 KB
#     pyasn1-0.6.1               |   py39haa95532_0         130 KB
#     pyasn1-modules-0.4.2       |   py39haa95532_0         368 KB
#     pyopenssl-23.2.0           |   py39haa95532_0          96 KB
#     python-3.9.18              |       h6244533_0        19.4 MB
#     python-flatbuffers-24.3.25 |   py39haa95532_0          57 KB
#     re2-2022.04.01             |       hd77b12b_0         374 KB
#     requests-oauthlib-2.0.0    |   py39haa95532_0          34 KB
#     rsa-4.7.2                  |     pyhd3eb1b0_1          28 KB
#     snappy-1.2.1               |       hcdb6601_0         108 KB
#     tensorboard-2.10.0         |   py39haa95532_0         5.6 MB
#     tensorboard-data-server-0.6.1|   py39haa95532_0          17 KB
#     tensorboard-plugin-wit-1.8.1|   py39haa95532_0         671 KB
#     tensorflow-2.10.0          |mkl_py39ha510bab_0           5 KB
#     tensorflow-base-2.10.0     |mkl_py39h6a7f48e_0        75.4 MB
#     tensorflow-estimator-2.10.0|   py39haa95532_0         491 KB
#     termcolor-2.1.0            |   py39haa95532_0          12 KB
#     werkzeug-3.1.3             |   py39haa95532_0         326 KB
#     wrapt-1.17.0               |   py39h827c3e9_0          61 KB
#     yarl-1.18.0                |   py39h827c3e9_0         143 KB
#     ------------------------------------------------------------
#                                            Total:       158.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _tflow_select      pkgs/main/win-64::_tflow_select-2.3.0-mkl
#   abseil-cpp         pkgs/main/win-64::abseil-cpp-20211102.0-hd77b12b_0
#   absl-py            pkgs/main/win-64::absl-py-2.1.0-py39haa95532_0
#   aiohappyeyeballs   pkgs/main/win-64::aiohappyeyeballs-2.6.1-py39haa95532_0
#   aiohttp            pkgs/main/win-64::aiohttp-3.11.10-py39h827c3e9_0
#   aiosignal          pkgs/main/win-64::aiosignal-1.4.0-py39haa95532_0
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0
#   async-timeout      pkgs/main/win-64::async-timeout-5.0.1-py39haa95532_0
#   c-ares             pkgs/main/win-64::c-ares-1.34.5-h731ff69_0
#   cachetools         pkgs/main/win-64::cachetools-5.5.1-py39haa95532_0
#   cryptography       pkgs/main/win-64::cryptography-41.0.3-py39h3438e0d_0
#   flatbuffers        pkgs/main/win-64::flatbuffers-25.2.10-hbdc3ed3_0
#   frozenlist         pkgs/main/win-64::frozenlist-1.5.0-py39h827c3e9_0
#   gast               pkgs/main/noarch::gast-0.4.0-pyhd3eb1b0_0
#   giflib             pkgs/main/win-64::giflib-5.2.2-h7edc060_0
#   google-auth        pkgs/main/win-64::google-auth-2.38.0-py39haa95532_1
#   google-auth-oauth~ pkgs/main/noarch::google-auth-oauthlib-0.4.4-pyhd3eb1b0_0
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-pyhd3eb1b0_0
#   grpc-cpp           pkgs/main/win-64::grpc-cpp-1.48.2-hf108199_0
#   grpcio             pkgs/main/win-64::grpcio-1.48.2-py39hf108199_0
#   h5py               pkgs/main/win-64::h5py-3.12.1-py39h535c9fb_1
#   hdf5               pkgs/main/win-64::hdf5-1.14.5-ha36df97_2
#   icu                pkgs/main/win-64::icu-58.2-ha925a31_3
#   jpeg               pkgs/main/win-64::jpeg-9e-h827c3e9_3
#   keras              pkgs/main/win-64::keras-2.10.0-py39haa95532_0
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.2-pyhd3eb1b0_0
#   libcurl            pkgs/main/win-64::libcurl-8.14.1-ha9f67de_0
#   libkrb5            pkgs/main/win-64::libkrb5-1.21.3-h885b0b7_4
#   libpng             pkgs/main/win-64::libpng-1.6.39-h8cc25b3_0
#   libprotobuf        pkgs/main/win-64::libprotobuf-3.20.3-h23ce68f_0
#   libssh2            pkgs/main/win-64::libssh2-1.10.0-hcd4344a_2
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.4-h2bbff1b_1
#   markdown           pkgs/main/win-64::markdown-3.8-py39haa95532_0
#   multidict          pkgs/main/win-64::multidict-6.1.0-py39h827c3e9_0
#   oauthlib           pkgs/main/win-64::oauthlib-3.3.1-py39haa95532_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.3.0-pyhd3eb1b0_1
#   propcache          pkgs/main/win-64::propcache-0.3.1-py39h827c3e9_0
#   protobuf           pkgs/main/win-64::protobuf-3.20.3-py39hd77b12b_0
#   pyasn1             pkgs/main/win-64::pyasn1-0.6.1-py39haa95532_0
#   pyasn1-modules     pkgs/main/win-64::pyasn1-modules-0.4.2-py39haa95532_0
#   pyopenssl          pkgs/main/win-64::pyopenssl-23.2.0-py39haa95532_0
#   python-flatbuffers pkgs/main/win-64::python-flatbuffers-24.3.25-py39haa95532_0
#   re2                pkgs/main/win-64::re2-2022.04.01-hd77b12b_0
#   requests-oauthlib  pkgs/main/win-64::requests-oauthlib-2.0.0-py39haa95532_0
#   rsa                pkgs/main/noarch::rsa-4.7.2-pyhd3eb1b0_1
#   snappy             pkgs/main/win-64::snappy-1.2.1-hcdb6601_0
#   tensorboard        pkgs/main/win-64::tensorboard-2.10.0-py39haa95532_0
#   tensorboard-data-~ pkgs/main/win-64::tensorboard-data-server-0.6.1-py39haa95532_0
#   tensorboard-plugi~ pkgs/main/win-64::tensorboard-plugin-wit-1.8.1-py39haa95532_0
#   tensorflow         pkgs/main/win-64::tensorflow-2.10.0-mkl_py39ha510bab_0
#   tensorflow-base    pkgs/main/win-64::tensorflow-base-2.10.0-mkl_py39h6a7f48e_0
#   tensorflow-estima~ pkgs/main/win-64::tensorflow-estimator-2.10.0-py39haa95532_0
#   termcolor          pkgs/main/win-64::termcolor-2.1.0-py39haa95532_0
#   werkzeug           pkgs/main/win-64::werkzeug-3.1.3-py39haa95532_0
#   wrapt              pkgs/main/win-64::wrapt-1.17.0-py39h827c3e9_0
#   yarl               pkgs/main/win-64::yarl-1.18.0-py39h827c3e9_0
#   zstd               pkgs/main/win-64::zstd-1.5.6-h8880b57_0
#
# The following packages will be UPDATED:
#
#   krb5                  conda-forge::krb5-1.21.3-hdf4eb48_0 --> pkgs/main::krb5-1.21.3-h885b0b7_4
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   openssl             conda-forge::openssl-3.5.2-h725018a_0 --> pkgs/main::openssl-1.1.1w-h2bbff1b_0
#
# The following packages will be DOWNGRADED:
#
#   python                                  3.9.23-h716150d_0 --> 3.9.18-h6244533_0
#
#
#
# Downloading and Extracting Packages: ...working...
# tensorflow-base-2.10 | 75.4 MB   |            |   0%
#
# grpc-cpp-1.48.2      | 23.5 MB   |            |   0%
#
#
# python-3.9.18        | 19.4 MB   |            |   0%
#
#
#
# icu-58.2             | 9.4 MB    |            |   0%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    |            |   0%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    |            |   0%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    |            |   0%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    |            |   0%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1.7 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.11.10      | 779 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.14.1       | 402 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2022.04.01       | 374 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# icu-58.2             | 9.4 MB    |            |   0%
#
# grpc-cpp-1.48.2      | 23.5 MB   |            |   0%
# tensorflow-base-2.10 | 75.4 MB   |            |   0%
#
# grpc-cpp-1.48.2      | 23.5 MB   | 1          |   2%
#
#
#
# icu-58.2             | 9.4 MB    | 4          |   4%
#
#
#
# icu-58.2             | 9.4 MB    | 6          |   6%
#
# grpc-cpp-1.48.2      | 23.5 MB   | 2          |   3%
# tensorflow-base-2.10 | 75.4 MB   |            |   0%
#
# grpc-cpp-1.48.2      | 23.5 MB   | 6          |   6%
#
#
#
# icu-58.2             | 9.4 MB    | #3         |  13%
#
# grpc-cpp-1.48.2      | 23.5 MB   | 8          |   8%
#
#
#
# icu-58.2             | 9.4 MB    | #9         |  19%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #1         |  12%
# tensorflow-base-2.10 | 75.4 MB   |            |   0%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    |            |   0%
#
#
#
# icu-58.2             | 9.4 MB    | ##7        |  28%
#
#
# python-3.9.18        | 19.4 MB   |            |   0%
# tensorflow-base-2.10 | 75.4 MB   |            |   0%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #3         |  14%
#
#
#
# icu-58.2             | 9.4 MB    | ###2       |  32%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | 1          |   1%
# tensorflow-base-2.10 | 75.4 MB   |            |   1%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #6         |  17%
#
#
#
# icu-58.2             | 9.4 MB    | ###7       |  38%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | 2          |   2%
#
#
# python-3.9.18        | 19.4 MB   |            |   0%
# tensorflow-base-2.10 | 75.4 MB   |            |   1%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #8         |  19%
#
#
# python-3.9.18        | 19.4 MB   |            |   1%
#
#
#
# icu-58.2             | 9.4 MB    | ####3      |  43%
# tensorflow-base-2.10 | 75.4 MB   |            |   1%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ##1        |  21%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | 3          |   3%
#
#
# python-3.9.18        | 19.4 MB   | 1          |   1%
#
#
#
# icu-58.2             | 9.4 MB    | #####1     |  51%
# tensorflow-base-2.10 | 75.4 MB   | 1          |   1%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | 6          |   6%
#
#
# python-3.9.18        | 19.4 MB   | 1          |   1%
# tensorflow-base-2.10 | 75.4 MB   | 1          |   1%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ##3        |  24%
#
#
# python-3.9.18        | 19.4 MB   | 2          |   3%
#
#
#
# icu-58.2             | 9.4 MB    | #####6     |  56%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | #2         |  12%
#
#
#
# icu-58.2             | 9.4 MB    | #####9     |  60%
#
#
# python-3.9.18        | 19.4 MB   | 3          |   4%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ##5        |  25%
#
#
#
# icu-58.2             | 9.4 MB    | ######3    |  63%
# tensorflow-base-2.10 | 75.4 MB   | 1          |   1%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | #3         |  14%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ##8        |  28%
#
#
# python-3.9.18        | 19.4 MB   | 4          |   5%
#
#
#
# icu-58.2             | 9.4 MB    | ######8    |  69%
# tensorflow-base-2.10 | 75.4 MB   | 1          |   1%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | #9         |  19%
#
#
# python-3.9.18        | 19.4 MB   | 6          |   7%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ##9        |  30%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ##3        |  23%
# tensorflow-base-2.10 | 75.4 MB   | 1          |   2%
#
#
# python-3.9.18        | 19.4 MB   | 8          |   8%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ##7        |  27%
# tensorflow-base-2.10 | 75.4 MB   | 2          |   2%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ###1       |  31%
#
#
#
# icu-58.2             | 9.4 MB    | #######3   |  73%
#
#
# python-3.9.18        | 19.4 MB   | 9          |   9%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ###1       |  31%
# tensorflow-base-2.10 | 75.4 MB   | 2          |   2%
#
#
# python-3.9.18        | 19.4 MB   | #          |  11%
#
#
#
# icu-58.2             | 9.4 MB    | #######7   |  77%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ###2       |  33%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ###5       |  35%
# tensorflow-base-2.10 | 75.4 MB   | 2          |   2%
#
#
#
# icu-58.2             | 9.4 MB    | ########1  |  81%
#
#
# python-3.9.18        | 19.4 MB   | #2         |  12%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ###4       |  34%
# tensorflow-base-2.10 | 75.4 MB   | 2          |   3%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ###9       |  39%
#
#
# python-3.9.18        | 19.4 MB   | #3         |  13%
# tensorflow-base-2.10 | 75.4 MB   | 2          |   3%
#
#
#
# icu-58.2             | 9.4 MB    | ########5  |  85%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ###5       |  36%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ####4      |  45%
#
#
# python-3.9.18        | 19.4 MB   | #4         |  15%
# tensorflow-base-2.10 | 75.4 MB   | 3          |   3%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ####9      |  49%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ###7       |  37%
#
#
#
# icu-58.2             | 9.4 MB    | ########8  |  88%
#
#
# python-3.9.18        | 19.4 MB   | #5         |  16%
# tensorflow-base-2.10 | 75.4 MB   | 3          |   3%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | #####3     |  53%
#
#
#
# icu-58.2             | 9.4 MB    | #########1 |  92%
#
#
# python-3.9.18        | 19.4 MB   | #7         |  17%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ###8       |  38%
# tensorflow-base-2.10 | 75.4 MB   | 3          |   4%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | #####7     |  57%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ###9       |  40%
#
#
# python-3.9.18        | 19.4 MB   | #8         |  18%
# tensorflow-base-2.10 | 75.4 MB   | 3          |   4%
#
#
#
# icu-58.2             | 9.4 MB    | #########4 |  95%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ######1    |  62%
#
#
# python-3.9.18        | 19.4 MB   | #9         |  20%
# tensorflow-base-2.10 | 75.4 MB   | 4          |   4%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ####       |  41%
#
#
#
# icu-58.2             | 9.4 MB    | #########7 |  97%
#
#
# python-3.9.18        | 19.4 MB   | ##         |  21%
# tensorflow-base-2.10 | 75.4 MB   | 4          |   4%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ######5    |  66%
#
#
#
# icu-58.2             | 9.4 MB    | ########## | 100%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ####1      |  42%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    |            |   0%
#
#
# python-3.9.18        | 19.4 MB   | ##2        |  22%
# tensorflow-base-2.10 | 75.4 MB   | 4          |   5%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | #######3   |  73%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ####3      |  44%
# tensorflow-base-2.10 | 75.4 MB   | 4          |   5%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | 4          |   4%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | #######7   |  78%
#
#
# python-3.9.18        | 19.4 MB   | ##3        |  23%
#
#
# python-3.9.18        | 19.4 MB   | ##4        |  24%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | 5          |   6%
# tensorflow-base-2.10 | 75.4 MB   | 5          |   5%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ########2  |  82%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #1         |  11%
#
#
# python-3.9.18        | 19.4 MB   | ##5        |  26%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ####4      |  45%
# tensorflow-base-2.10 | 75.4 MB   | 5          |   6%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ########6  |  87%
#
#
# python-3.9.18        | 19.4 MB   | ##7        |  27%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ####6      |  46%
# tensorflow-base-2.10 | 75.4 MB   | 5          |   6%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #7         |  17%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | #########2 |  92%
#
#
# python-3.9.18        | 19.4 MB   | ##8        |  28%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ##1        |  22%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ####8      |  48%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | #########6 |  96%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ##5        |  26%
#
#
# python-3.9.18        | 19.4 MB   | ##9        |  30%
# tensorflow-base-2.10 | 75.4 MB   | 6          |   6%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ####9      |  50%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ########## | 100%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ###2       |  32%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    |            |   1%
# tensorflow-base-2.10 | 75.4 MB   | 6          |   7%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #####      |  51%
#
#
# python-3.9.18        | 19.4 MB   | ###1       |  31%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ###6       |  37%
# tensorflow-base-2.10 | 75.4 MB   | 7          |   7%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | 1          |   1%
#
#
#
# icu-58.2             | 9.4 MB    | ########## | 100%
#
#
#
# icu-58.2             | 9.4 MB    | ########## | 100%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #####1     |  52%
#
#
# python-3.9.18        | 19.4 MB   | ###2       |  33%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ####1      |  42%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | #9         |  20%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #####3     |  53%
#
#
# python-3.9.18        | 19.4 MB   | ###3       |  34%
# tensorflow-base-2.10 | 75.4 MB   | 7          |   8%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ####6      |  46%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | ###4       |  35%
# tensorflow-base-2.10 | 75.4 MB   | 7          |   8%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #####4     |  54%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #####      |  50%
#
#
# python-3.9.18        | 19.4 MB   | ###4       |  35%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | ####5      |  45%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #####4     |  54%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #####5     |  55%
# tensorflow-base-2.10 | 75.4 MB   | 8          |   8%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ######     |  61%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | #####8     |  58%
# tensorflow-base-2.10 | 75.4 MB   | 8          |   9%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #####7     |  57%
#
#
# python-3.9.18        | 19.4 MB   | ###5       |  36%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ######5    |  65%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | ######7    |  68%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #####8     |  59%
# tensorflow-base-2.10 | 75.4 MB   | 9          |   9%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #######    |  71%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | #######9   |  79%
#
#
# python-3.9.18        | 19.4 MB   | ###6       |  37%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #####9     |  60%
# tensorflow-base-2.10 | 75.4 MB   | 9          |  10%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | ########9  |  89%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ######1    |  61%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #######5   |  76%
#
#
# python-3.9.18        | 19.4 MB   | ###7       |  38%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | ########## | 100%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | ########## | 100%
# tensorflow-base-2.10 | 75.4 MB   | #          |  10%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #######9   |  80%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ######2    |  62%
# tensorflow-base-2.10 | 75.4 MB   | #          |  11%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    |            |   1%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ########5  |  86%
#
#
# python-3.9.18        | 19.4 MB   | ###8       |  38%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ######3    |  64%
# tensorflow-base-2.10 | 75.4 MB   | #1         |  11%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | #1         |  12%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #########  |  90%
#
#
# python-3.9.18        | 19.4 MB   | ###8       |  39%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #########6 |  96%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ######5    |  65%
#
#
#
#
# tensorboard-2.10.0   | 5.6 MB    | ########## | 100%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ##1        |  21%
# tensorflow-base-2.10 | 75.4 MB   | #1         |  11%
#
#
# python-3.9.18        | 19.4 MB   | ###9       |  40%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ########## | 100%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ######6    |  67%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ###4       |  34%
# tensorflow-base-2.10 | 75.4 MB   | #1         |  12%
#
#
# python-3.9.18        | 19.4 MB   | ####       |  40%
#
#
#
#
#
#
# libprotobuf-3.20.3   | 2.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    |            |   1%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ######8    |  68%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ####8      |  49%
#
#
# python-3.9.18        | 19.4 MB   | ####       |  41%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    | 8          |   9%
# tensorflow-base-2.10 | 75.4 MB   | #2         |  12%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | #####9     |  60%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ######9    |  70%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    | ##2        |  23%
#
#
# python-3.9.18        | 19.4 MB   | ####1      |  41%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #######    |  71%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    | ###4       |  35%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | #######3   |  74%
#
#
# python-3.9.18        | 19.4 MB   | ####1      |  42%
# tensorflow-base-2.10 | 75.4 MB   | #2         |  13%
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    | ####4      |  45%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #######1   |  72%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ########2  |  83%
# tensorflow-base-2.10 | 75.4 MB   | #2         |  13%
#
#
# python-3.9.18        | 19.4 MB   | ####2      |  42%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    | #####5     |  55%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #######2   |  73%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ####3      |  43%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    | #######2   |  73%
# tensorflow-base-2.10 | 75.4 MB   | #3         |  13%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    |            |   1%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #######4   |  74%
# tensorflow-base-2.10 | 75.4 MB   | #4         |  14%
#
#
# python-3.9.18        | 19.4 MB   | ####3      |  44%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    | ########4  |  84%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    | #1         |  11%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #######5   |  75%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    | #########6 |  96%
#
#
# python-3.9.18        | 19.4 MB   | ####4      |  44%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    | ##9        |  29%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    | ########## | 100%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #######6   |  77%
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1.7 MB    |            |   1%
# tensorflow-base-2.10 | 75.4 MB   | #4         |  15%
#
#
# python-3.9.18        | 19.4 MB   | ####4      |  45%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    | ####3      |  44%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #######7   |  78%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ########## | 100%
#
#
#
#
#
#
#
# hdf5-1.14.5          | 2.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1.7 MB    | #5         |  15%
# tensorflow-base-2.10 | 75.4 MB   | #5         |  15%
#
#
# python-3.9.18        | 19.4 MB   | ####5      |  45%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    | #####5     |  56%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #######8   |  79%
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1.7 MB    | ##9        |  29%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    | ######7    |  68%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #######9   |  80%
#
#
# python-3.9.18        | 19.4 MB   | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1.7 MB    | ####       |  41%
# tensorflow-base-2.10 | 75.4 MB   | #5         |  16%
#
#
#
#
#
#
#
#
# grpcio-1.48.2        | 2.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    | #######9   |  80%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########   |  81%
#
#
# python-3.9.18        | 19.4 MB   | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1.7 MB    | ######     |  61%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    | #########1 |  92%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########2  |  82%
# tensorflow-base-2.10 | 75.4 MB   | #6         |  16%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1.7 MB    | #######5   |  76%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########3  |  83%
# tensorflow-base-2.10 | 75.4 MB   | #6         |  17%
#
#
# python-3.9.18        | 19.4 MB   | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1.7 MB    | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1.7 MB    | ########## | 100%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########4  |  85%
#
#
#
#
#
#
#
#
#
# flatbuffers-25.2.10  | 2.0 MB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ####8      |  49%
# tensorflow-base-2.10 | 75.4 MB   | #7         |  17%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########5  |  86%
#
#
# python-3.9.18        | 19.4 MB   | ####9      |  50%
# tensorflow-base-2.10 | 75.4 MB   | #7         |  18%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########7  |  87%
#
#
# python-3.9.18        | 19.4 MB   | #####      |  51%
# tensorflow-base-2.10 | 75.4 MB   | #8         |  18%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########9  |  89%
#
#
# python-3.9.18        | 19.4 MB   | #####1     |  52%
# tensorflow-base-2.10 | 75.4 MB   | #8         |  19%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #########  |  91%
#
#
# python-3.9.18        | 19.4 MB   | #####2     |  53%
# tensorflow-base-2.10 | 75.4 MB   | #9         |  19%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | 1          |   1%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #########2 |  93%
#
#
# python-3.9.18        | 19.4 MB   | #####3     |  54%
# tensorflow-base-2.10 | 75.4 MB   | #9         |  20%
# tensorflow-base-2.10 | 75.4 MB   | ##         |  20%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #########4 |  94%
#
#
# python-3.9.18        | 19.4 MB   | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | 4          |   4%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #########5 |  96%
#
#
# python-3.9.18        | 19.4 MB   | #####5     |  56%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | 8          |   8%
# tensorflow-base-2.10 | 75.4 MB   | ##         |  21%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | #3         |  13%
#
#
# python-3.9.18        | 19.4 MB   | #####6     |  56%
# tensorflow-base-2.10 | 75.4 MB   | ##1        |  22%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | #8         |  18%
#
# grpc-cpp-1.48.2      | 23.5 MB   | #########9 | 100%
#
#
# python-3.9.18        | 19.4 MB   | #####7     |  57%
# tensorflow-base-2.10 | 75.4 MB   | ##2        |  22%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | ##6        |  26%
#
#
# python-3.9.18        | 19.4 MB   | #####8     |  58%
# tensorflow-base-2.10 | 75.4 MB   | ##2        |  23%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | ###5       |  35%
#
#
# python-3.9.18        | 19.4 MB   | #####9     |  59%
# tensorflow-base-2.10 | 75.4 MB   | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | ####6      |  46%
#
#
# python-3.9.18        | 19.4 MB   | ######     |  60%
# tensorflow-base-2.10 | 75.4 MB   | ##3        |  24%
#
#
#
#
#
#
#
#
#
#
# abseil-cpp-20211102. | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | ######3    |  64%
#
#
# python-3.9.18        | 19.4 MB   | ######1    |  61%
# tensorflow-base-2.10 | 75.4 MB   | ##4        |  24%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | ########   |  81%
#
#
# python-3.9.18        | 19.4 MB   | ######2    |  62%
# tensorflow-base-2.10 | 75.4 MB   | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ######3    |  63%
# tensorflow-base-2.10 | 75.4 MB   | ##5        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.11.10      | 779 KB    | 2          |   2%
#
#
# python-3.9.18        | 19.4 MB   | ######4    |  65%
# tensorflow-base-2.10 | 75.4 MB   | ##6        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.11.10      | 779 KB    | ####9      |  49%
#
#
# python-3.9.18        | 19.4 MB   | ######6    |  67%
# tensorflow-base-2.10 | 75.4 MB   | ##6        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.11.10      | 779 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.11.10      | 779 KB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ######7    |  68%
# tensorflow-base-2.10 | 75.4 MB   | ##7        |  27%
#
#
# python-3.9.18        | 19.4 MB   | ######9    |  69%
# tensorflow-base-2.10 | 75.4 MB   | ##8        |  28%
# tensorflow-base-2.10 | 75.4 MB   | ##9        |  29%
#
#
# python-3.9.18        | 19.4 MB   | #######    |  71%
# tensorflow-base-2.10 | 75.4 MB   | ##9        |  30%
#
#
# python-3.9.18        | 19.4 MB   | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | 1          |   1%
# tensorflow-base-2.10 | 75.4 MB   | ###        |  31%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | 1          |   1%
#
#
# python-3.9.18        | 19.4 MB   | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | 4          |   4%
# tensorflow-base-2.10 | 75.4 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | 4          |   4%
#
#
# python-3.9.18        | 19.4 MB   | #######4   |  75%
# tensorflow-base-2.10 | 75.4 MB   | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | 8          |   8%
#
#
# python-3.9.18        | 19.4 MB   | #######6   |  76%
# tensorflow-base-2.10 | 75.4 MB   | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | 7          |   7%
# tensorflow-base-2.10 | 75.4 MB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | #5         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.11.10      | 779 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | ##3        |  23%
#
#
# python-3.9.18        | 19.4 MB   | #######7   |  77%
# tensorflow-base-2.10 | 75.4 MB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | ##2        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | ###        |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | ####       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | ##8        |  29%
#
#
# python-3.9.18        | 19.4 MB   | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | ####6      |  46%
# tensorflow-base-2.10 | 75.4 MB   | ###7       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | ####5      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | #####8     |  59%
#
#
# python-3.9.18        | 19.4 MB   | #######9   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | #######8   |  78%
# tensorflow-base-2.10 | 75.4 MB   | ###8       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | #####7     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | #######    |  70%
# tensorflow-base-2.10 | 75.4 MB   | ###9       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    | 3          |   3%
# tensorflow-base-2.10 | 75.4 MB   | ####       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | #########  |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.14.1       | 402 KB    | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ########   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    | #########1 |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.14.1       | 402 KB    | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2022.04.01       | 374 KB    | 4          |   4%
# tensorflow-base-2.10 | 75.4 MB   | ####1      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.14.1       | 402 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ########   |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2022.04.01       | 374 KB    | ####7      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# tensorflow-base-2.10 | 75.4 MB   | ####1      |  42%
# tensorflow-base-2.10 | 75.4 MB   | ####3      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# python-3.9.18        | 19.4 MB   | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2022.04.01       | 374 KB    | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2022.04.01       | 374 KB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-3.12.1          | 1.1 MB    | ########## | 100%
# tensorflow-base-2.10 | 75.4 MB   | ####4      |  45%
#
#
# python-3.9.18        | 19.4 MB   | ########3  |  83%
# tensorflow-base-2.10 | 75.4 MB   | ####5      |  46%
#
#
# python-3.9.18        | 19.4 MB   | ########4  |  84%
#
# grpc-cpp-1.48.2      | 23.5 MB   | ########## | 100%
# tensorflow-base-2.10 | 75.4 MB   | ####6      |  46%
#
#
# python-3.9.18        | 19.4 MB   | ########4  |  85%
# tensorflow-base-2.10 | 75.4 MB   | ####7      |  47%
#
#
# python-3.9.18        | 19.4 MB   | ########5  |  85%
# tensorflow-base-2.10 | 75.4 MB   | ####7      |  48%
#
#
# python-3.9.18        | 19.4 MB   | ########6  |  86%
# tensorflow-base-2.10 | 75.4 MB   | ####9      |  50%
#
#
# python-3.9.18        | 19.4 MB   | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-plugin-w | 671 KB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ########7  |  88%
# tensorflow-base-2.10 | 75.4 MB   | #####      |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.14.1       | 402 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.14.1       | 402 KB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ########8  |  89%
# tensorflow-base-2.10 | 75.4 MB   | #####2     |  53%
#
#
# python-3.9.18        | 19.4 MB   | ########9  |  89%
# tensorflow-base-2.10 | 75.4 MB   | #####4     |  54%
#
#
# python-3.9.18        | 19.4 MB   | #########  |  90%
# tensorflow-base-2.10 | 75.4 MB   | #####5     |  55%
#
#
# python-3.9.18        | 19.4 MB   | #########1 |  91%
# tensorflow-base-2.10 | 75.4 MB   | #####6     |  56%
#
#
# python-3.9.18        | 19.4 MB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cryptography-41.0.3  | 1.1 MB    | ########## | 100%
# tensorflow-base-2.10 | 75.4 MB   | #####7     |  57%
#
#
# python-3.9.18        | 19.4 MB   | #########3 |  93%
# tensorflow-base-2.10 | 75.4 MB   | #####8     |  59%
#
#
# python-3.9.18        | 19.4 MB   | #########4 |  94%
# tensorflow-base-2.10 | 75.4 MB   | #####9     |  60%
#
#
# python-3.9.18        | 19.4 MB   | #########5 |  95%
# tensorflow-base-2.10 | 75.4 MB   | ######     |  61%
#
#
# python-3.9.18        | 19.4 MB   | #########6 |  96%
# tensorflow-base-2.10 | 75.4 MB   | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-estimator | 491 KB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | #########7 |  97%
# tensorflow-base-2.10 | 75.4 MB   | ######2    |  63%
#
#
# python-3.9.18        | 19.4 MB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2022.04.01       | 374 KB    | ########## | 100%
# tensorflow-base-2.10 | 75.4 MB   | ######4    |  64%
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 1.5 MB    | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | #########8 |  99%
# tensorflow-base-2.10 | 75.4 MB   | ######6    |  67%
# tensorflow-base-2.10 | 75.4 MB   | ######8    |  68%
#
#
# python-3.9.18        | 19.4 MB   | #########9 | 100%
# tensorflow-base-2.10 | 75.4 MB   | ######9    |  70%
# tensorflow-base-2.10 | 75.4 MB   | #######1   |  71%
# tensorflow-base-2.10 | 75.4 MB   | #######2   |  72%
#
#
# python-3.9.18        | 19.4 MB   | ########## | 100%
# tensorflow-base-2.10 | 75.4 MB   | #######3   |  74%
# tensorflow-base-2.10 | 75.4 MB   | #######5   |  75%
# tensorflow-base-2.10 | 75.4 MB   | #######6   |  77%
# tensorflow-base-2.10 | 75.4 MB   | #######8   |  78%
# tensorflow-base-2.10 | 75.4 MB   | ########   |  80%
# tensorflow-base-2.10 | 75.4 MB   | ########1  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# tensorflow-base-2.10 | 75.4 MB   | ########3  |  83%
# tensorflow-base-2.10 | 75.4 MB   | ########4  |  85%
# tensorflow-base-2.10 | 75.4 MB   | ########6  |  87%
# tensorflow-base-2.10 | 75.4 MB   | ########8  |  89%
# tensorflow-base-2.10 | 75.4 MB   | #########  |  90%
# tensorflow-base-2.10 | 75.4 MB   | #########1 |  92%
# tensorflow-base-2.10 | 75.4 MB   | #########3 |  94%
# tensorflow-base-2.10 | 75.4 MB   | #########5 |  96%
# tensorflow-base-2.10 | 75.4 MB   | #########7 |  97%
# tensorflow-base-2.10 | 75.4 MB   | #########9 | 100%
# tensorflow-base-2.10 | 75.4 MB   | ########## | 100%
#
#
# python-3.9.18        | 19.4 MB   | ########## | 100%
# tensorflow-base-2.10 | 75.4 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Define the model architecture
model = Sequential()

# Add the first LSTM layer with Dropout regularization
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))

# Add a second LSTM layer with Dropout regularization
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))

# Add the output layer
# It has 1 unit because we are predicting 1 value (the 'Close' price)
model.add(Dense(units=1))

# Compile the model
# This configures the model for training
model.compile(optimizer='adam', loss='mean_squared_error')

print("✅ LSTM Model has been successfully built and compiled.")

# Display the model's architecture
model.summary()
# Out:
# ✅ LSTM Model has been successfully built and compiled.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            11200
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 31,451
# Trainable params: 31,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
print("Starting model training... this will take several minutes.")

# Train the model
# epochs=50 means the model will see the entire dataset 50 times
# batch_size=32 means the model will look at 32 samples at a time
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

print("\n✅✅✅ Model training complete!")
# Out:
# Starting model training... this will take several minutes.
# Epoch 1/50
# 34/34 [==============================] - 13s 157ms/step - loss: 0.0561 - val_loss: 0.0056
# Epoch 2/50
# 34/34 [==============================] - 3s 84ms/step - loss: 0.0087 - val_loss: 0.0032
# Epoch 3/50
# 34/34 [==============================] - 3s 103ms/step - loss: 0.0059 - val_loss: 0.0019
# Epoch 4/50
# 34/34 [==============================] - 3s 103ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 5/50
# 34/34 [==============================] - 4s 107ms/step - loss: 0.0046 - val_loss: 0.0011
# Epoch 6/50
# 34/34 [==============================] - 3s 94ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 7/50
# 34/34 [==============================] - 4s 108ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 8/50
# 34/34 [==============================] - 4s 107ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 9/50
# 34/34 [==============================] - 3s 84ms/step - loss: 0.0035 - val_loss: 0.0010
# Epoch 10/50
# 34/34 [==============================] - 4s 103ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 11/50
# 34/34 [==============================] - 3s 95ms/step - loss: 0.0036 - val_loss: 0.0012
# Epoch 12/50
# 34/34 [==============================] - 7s 200ms/step - loss: 0.0027 - val_loss: 8.0140e-04
# Epoch 29/50
# 34/34 [==============================] - 6s 186ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 30/50
# 34/34 [==============================] - 7s 193ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 31/50
# 34/34 [==============================] - 7s 196ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 32/50
# 34/34 [==============================] - 7s 193ms/step - loss: 0.0027 - val_loss: 8.7487e-04
# Epoch 33/50
# 34/34 [==============================] - 7s 192ms/step - loss: 0.0026 - val_loss: 6.3028e-04
# Epoch 34/50
# 34/34 [==============================] - 7s 198ms/step - loss: 0.0025 - val_loss: 9.7880e-04
# Epoch 35/50
# 34/34 [==============================] - 6s 186ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 36/50
# 34/34 [==============================] - 7s 192ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 37/50
# 34/34 [==============================] - 7s 196ms/step - loss: 0.0022 - val_loss: 9.0583e-04
# Epoch 38/50
# 34/34 [==============================] - 7s 200ms/step - loss: 0.0023 - val_loss: 9.6096e-04
# Epoch 39/50
# 34/34 [==============================] - 6s 187ms/step - loss: 0.0025 - val_loss: 6.6404e-04
# Epoch 40/50
# 34/34 [==============================] - 6s 188ms/step - loss: 0.0022 - val_loss: 6.6378e-04
# Epoch 41/50
# 34/34 [==============================] - 6s 191ms/step - loss: 0.0021 - val_loss: 6.3637e-04
# Epoch 42/50
# 34/34 [==============================] - 7s 200ms/step - loss: 0.0024 - val_loss: 6.0954e-04
# Epoch 43/50
# 34/34 [==============================] - 6s 190ms/step - loss: 0.0022 - val_loss: 6.0700e-04
# Epoch 44/50
# 34/34 [==============================] - 7s 192ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 45/50
# 34/34 [==============================] - 6s 191ms/step - loss: 0.0023 - val_loss: 0.0010
# Epoch 46/50
# 34/34 [==============================] - 7s 194ms/step - loss: 0.0020 - val_loss: 5.7058e-04
# Epoch 47/50
# 34/34 [==============================] - 7s 194ms/step - loss: 0.0020 - val_loss: 8.0388e-04
# Epoch 48/50
# 34/34 [==============================] - 7s 197ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 49/50
# 34/34 [==============================] - 7s 198ms/step - loss: 0.0020 - val_loss: 6.4782e-04
# Epoch 50/50
# 34/34 [==============================] - 6s 189ms/step - loss: 0.0020 - val_loss: 9.4966e-04
#
# ✅✅✅ Model training complete!

# %%
# !conda install matplotlib -y
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\devGo\.conda\envs\capstone_v2
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     contourpy-1.2.1            |   py39h214f63a_1         202 KB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     fonttools-4.55.3           |   py39h827c3e9_0         2.1 MB
#     glib-2.84.2                |       h232b036_0         523 KB
#     glib-tools-2.84.2          |       h08ed4da_0         118 KB
#     gst-plugins-base-1.18.5    |       h9e645db_0         1.7 MB
#     gstreamer-1.18.5           |       hd78058f_0         1.7 MB
#     importlib_resources-6.4.0  |   py39haa95532_0          61 KB
#     kiwisolver-1.4.4           |   py39hd77b12b_0          60 KB
#     lcms2-2.16                 |       hb4a4139_0         566 KB
#     lerc-3.0                   |       hd77b12b_0         120 KB
#     libclang-12.0.0            |default_h627e005_2        17.8 MB
#     libdeflate-1.17            |       h2bbff1b_1         153 KB
#     libogg-1.3.5               |       h2bbff1b_1          33 KB
#     libtiff-4.5.1              |       hd77b12b_0         1.1 MB
#     libvorbis-1.3.7            |       he774522_0         202 KB
#     libwebp-base-1.3.2         |       h3d04722_1         303 KB
#     matplotlib-3.9.2           |   py39haa95532_1           8 KB
#     matplotlib-base-3.9.2      |   py39he19b0ae_1         9.2 MB
#     openjpeg-2.5.2             |       hae555c5_0         268 KB
#     pillow-11.1.0              |   py39h096bfcc_0         759 KB
#     ply-3.11                   |   py39haa95532_0          81 KB
#     pyparsing-3.2.0            |   py39haa95532_0         422 KB
#     pyqt-5.15.10               |   py39h5da7b33_1         4.2 MB
#     pyqt5-sip-12.13.0          |   py39h827c3e9_1          86 KB
#     qt-main-5.15.2             |       he8e5bd7_7        50.0 MB
#     sip-6.7.12                 |   py39h5da7b33_1         528 KB
#     unicodedata2-15.1.0        |   py39h827c3e9_1         525 KB
#     ------------------------------------------------------------
#                                            Total:        92.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   contourpy          pkgs/main/win-64::contourpy-1.2.1-py39h214f63a_1
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/win-64::fonttools-4.55.3-py39h827c3e9_0
#   freetype           pkgs/main/win-64::freetype-2.13.3-h0620614_0
#   glib               pkgs/main/win-64::glib-2.84.2-h232b036_0
#   glib-tools         pkgs/main/win-64::glib-tools-2.84.2-h08ed4da_0
#   gst-plugins-base   pkgs/main/win-64::gst-plugins-base-1.18.5-h9e645db_0
#   gstreamer          pkgs/main/win-64::gstreamer-1.18.5-hd78058f_0
#   importlib_resourc~ pkgs/main/win-64::importlib_resources-6.4.0-py39haa95532_0
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.4.4-py39hd77b12b_0
#   lcms2              pkgs/main/win-64::lcms2-2.16-hb4a4139_0
#   lerc               pkgs/main/win-64::lerc-3.0-hd77b12b_0
#   libclang           pkgs/main/win-64::libclang-12.0.0-default_h627e005_2
#   libdeflate         pkgs/main/win-64::libdeflate-1.17-h2bbff1b_1
#   libglib            pkgs/main/win-64::libglib-2.84.2-h405b238_0
#   libogg             pkgs/main/win-64::libogg-1.3.5-h2bbff1b_1
#   libtiff            pkgs/main/win-64::libtiff-4.5.1-hd77b12b_0
#   libvorbis          pkgs/main/win-64::libvorbis-1.3.7-he774522_0
#   libwebp-base       pkgs/main/win-64::libwebp-base-1.3.2-h3d04722_1
#   matplotlib         pkgs/main/win-64::matplotlib-3.9.2-py39haa95532_1
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.9.2-py39he19b0ae_1
#   openjpeg           pkgs/main/win-64::openjpeg-2.5.2-hae555c5_0
#   pcre2              pkgs/main/win-64::pcre2-10.42-h0ff8eda_1
#   pillow             pkgs/main/win-64::pillow-11.1.0-py39h096bfcc_0
#   ply                pkgs/main/win-64::ply-3.11-py39haa95532_0
#   pyparsing          pkgs/main/win-64::pyparsing-3.2.0-py39haa95532_0
#   pyqt               pkgs/main/win-64::pyqt-5.15.10-py39h5da7b33_1
#   pyqt5-sip          pkgs/main/win-64::pyqt5-sip-12.13.0-py39h827c3e9_1
#   qt-main            pkgs/main/win-64::qt-main-5.15.2-he8e5bd7_7
#   sip                pkgs/main/win-64::sip-6.7.12-py39h5da7b33_1
#   unicodedata2       pkgs/main/win-64::unicodedata2-15.1.0-py39h827c3e9_1
#
#
#
# Downloading and Extracting Packages: ...working...
# qt-main-5.15.2       | 50.0 MB   |            |   0%
#
# libclang-12.0.0      | 17.8 MB   |            |   0%
#
#
# matplotlib-base-3.9. | 9.2 MB    |            |   0%
#
#
#
# pyqt-5.15.10         | 4.2 MB    |            |   0%
#
#
#
#
# fonttools-4.55.3     | 2.1 MB    |            |   0%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    |            |   0%
#
#
#
#
#
#
# gstreamer-1.18.5     | 1.7 MB    |            |   0%
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 759 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 566 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 528 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 525 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.2          | 523 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 422 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 303 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 268 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvorbis-1.3.7      | 202 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.1      | 202 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 153 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libclang-12.0.0      | 17.8 MB   |            |   0%
#
#
#
#
# fonttools-4.55.3     | 2.1 MB    |            |   1%
#
#
#
# pyqt-5.15.10         | 4.2 MB    |            |   0%
# qt-main-5.15.2       | 50.0 MB   |            |   0%
#
# libclang-12.0.0      | 17.8 MB   | 1          |   1%
#
#
# matplotlib-base-3.9. | 9.2 MB    |            |   0%
#
#
#
#
# fonttools-4.55.3     | 2.1 MB    | #4         |  15%
# qt-main-5.15.2       | 50.0 MB   |            |   1%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | 4          |   5%
#
# libclang-12.0.0      | 17.8 MB   | 2          |   2%
# qt-main-5.15.2       | 50.0 MB   |            |   1%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | #          |  10%
#
#
#
#
# fonttools-4.55.3     | 2.1 MB    | ####2      |  43%
#
#
# matplotlib-base-3.9. | 9.2 MB    | 1          |   2%
#
# libclang-12.0.0      | 17.8 MB   | 4          |   4%
# qt-main-5.15.2       | 50.0 MB   | 1          |   1%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | #5         |  15%
#
#
# matplotlib-base-3.9. | 9.2 MB    | 3          |   3%
#
#
#
#
# fonttools-4.55.3     | 2.1 MB    | ######     |  61%
#
# libclang-12.0.0      | 17.8 MB   | 5          |   5%
# qt-main-5.15.2       | 50.0 MB   | 1          |   2%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ##2        |  23%
#
#
#
#
# fonttools-4.55.3     | 2.1 MB    | #######5   |  75%
#
#
# matplotlib-base-3.9. | 9.2 MB    | 5          |   6%
# qt-main-5.15.2       | 50.0 MB   | 2          |   2%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ##7        |  27%
#
# libclang-12.0.0      | 17.8 MB   | 6          |   6%
#
#
# matplotlib-base-3.9. | 9.2 MB    | 7          |   8%
#
#
#
#
# fonttools-4.55.3     | 2.1 MB    | ########8  |  89%
# qt-main-5.15.2       | 50.0 MB   | 2          |   3%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ###2       |  32%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #          |  10%
#
# libclang-12.0.0      | 17.8 MB   | 8          |   8%
#
#
#
#
# fonttools-4.55.3     | 2.1 MB    | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | 3          |   3%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ###9       |  40%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    |            |   1%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #4         |  14%
#
# libclang-12.0.0      | 17.8 MB   | 9          |  10%
# qt-main-5.15.2       | 50.0 MB   | 3          |   4%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    | 7          |   7%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #6         |  17%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ####5      |  45%
#
# libclang-12.0.0      | 17.8 MB   | #1         |  11%
# qt-main-5.15.2       | 50.0 MB   | 4          |   4%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    | #6         |  16%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #9         |  20%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | #####      |  51%
#
# libclang-12.0.0      | 17.8 MB   | #2         |  13%
# qt-main-5.15.2       | 50.0 MB   | 4          |   5%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    | ###4       |  34%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ##1        |  22%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | #####7     |  57%
#
# libclang-12.0.0      | 17.8 MB   | #4         |  14%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    | ####7      |  47%
# qt-main-5.15.2       | 50.0 MB   | 5          |   5%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ######4    |  64%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ##4        |  24%
#
# libclang-12.0.0      | 17.8 MB   | #6         |  16%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    | ######2    |  63%
# qt-main-5.15.2       | 50.0 MB   | 5          |   6%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ######9    |  70%
#
# libclang-12.0.0      | 17.8 MB   | #7         |  18%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    | #######5   |  75%
# qt-main-5.15.2       | 50.0 MB   | 6          |   6%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | #######5   |  75%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    | #########2 |  93%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ##7        |  28%
#
# libclang-12.0.0      | 17.8 MB   | #9         |  19%
# qt-main-5.15.2       | 50.0 MB   | 6          |   7%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    | ########## | 100%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ########1  |  81%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ###        |  31%
#
# libclang-12.0.0      | 17.8 MB   | ##         |  20%
#
#
#
#
#
#
# gstreamer-1.18.5     | 1.7 MB    |            |   1%
# qt-main-5.15.2       | 50.0 MB   | 7          |   7%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ########8  |  88%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ###6       |  36%
#
# libclang-12.0.0      | 17.8 MB   | ##1        |  22%
#
#
#
#
#
#
# gstreamer-1.18.5     | 1.7 MB    | #3         |  14%
# qt-main-5.15.2       | 50.0 MB   | 7          |   8%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | #########3 |  94%
#
#
#
#
#
#
# gstreamer-1.18.5     | 1.7 MB    | ##6        |  27%
#
# libclang-12.0.0      | 17.8 MB   | ##3        |  23%
# qt-main-5.15.2       | 50.0 MB   | 8          |   8%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | #########9 | 100%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ########## | 100%
#
#
#
#
#
#
# gstreamer-1.18.5     | 1.7 MB    | ###7       |  37%
#
# libclang-12.0.0      | 17.8 MB   | ##4        |  24%
# qt-main-5.15.2       | 50.0 MB   | 8          |   9%
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | 1          |   1%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ###9       |  40%
#
#
#
#
#
#
# gstreamer-1.18.5     | 1.7 MB    | #####6     |  57%
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ##         |  21%
#
# libclang-12.0.0      | 17.8 MB   | ##6        |  26%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ####5      |  46%
# qt-main-5.15.2       | 50.0 MB   | 9          |   9%
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ###5       |  35%
#
#
#
#
#
#
# gstreamer-1.18.5     | 1.7 MB    | ######9    |  70%
# qt-main-5.15.2       | 50.0 MB   | 9          |  10%
#
# libclang-12.0.0      | 17.8 MB   | ##7        |  28%
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ######3    |  63%
#
#
#
#
#
#
# gstreamer-1.18.5     | 1.7 MB    | ########8  |  88%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ####9      |  50%
# qt-main-5.15.2       | 50.0 MB   | #          |  10%
#
# libclang-12.0.0      | 17.8 MB   | ##9        |  30%
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ########2  |  83%
#
#
#
#
#
#
# gstreamer-1.18.5     | 1.7 MB    | ########## | 100%
#
#
#
#
# fonttools-4.55.3     | 2.1 MB    | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | #          |  11%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #####2     |  53%
#
# libclang-12.0.0      | 17.8 MB   | ###1       |  31%
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 759 KB    | 2          |   2%
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 566 KB    | 2          |   3%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #####6     |  57%
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 759 KB    | ###1       |  32%
# qt-main-5.15.2       | 50.0 MB   | #1         |  11%
#
# libclang-12.0.0      | 17.8 MB   | ###2       |  32%
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 566 KB    | ##8        |  28%
#
#
#
#
#
# gst-plugins-base-1.1 | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 759 KB    | ####8      |  48%
#
# libclang-12.0.0      | 17.8 MB   | ###3       |  34%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ######     |  60%
# qt-main-5.15.2       | 50.0 MB   | #1         |  12%
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 566 KB    | #######9   |  79%
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 759 KB    | ########6  |  86%
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 566 KB    | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   | ###5       |  35%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ######2    |  63%
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 759 KB    | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 525 KB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 528 KB    | 3          |   3%
#
# libclang-12.0.0      | 17.8 MB   | ###7       |  37%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ######5    |  66%
# qt-main-5.15.2       | 50.0 MB   | #3         |  13%
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 528 KB    | ####5      |  45%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 525 KB    | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 528 KB    | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 525 KB    | ########2  |  82%
# qt-main-5.15.2       | 50.0 MB   | #3         |  14%
#
# libclang-12.0.0      | 17.8 MB   | ###8       |  38%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ######8    |  68%
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 528 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 525 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.2          | 523 KB    | 3          |   3%
#
# libclang-12.0.0      | 17.8 MB   | ####1      |  41%
# qt-main-5.15.2       | 50.0 MB   | #4         |  14%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.2          | 523 KB    | #####2     |  52%
# qt-main-5.15.2       | 50.0 MB   | #5         |  15%
#
# libclang-12.0.0      | 17.8 MB   | ####2      |  43%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #######5   |  76%
#
#
#
#
#
#
# gstreamer-1.18.5     | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.2          | 523 KB    | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | #5         |  16%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #######8   |  79%
#
# libclang-12.0.0      | 17.8 MB   | ####4      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 422 KB    | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 303 KB    | 5          |   5%
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 566 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 422 KB    | ####1      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 303 KB    | ###7       |  37%
#
# libclang-12.0.0      | 17.8 MB   | ####5      |  46%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ########1  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 303 KB    | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | #6         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 422 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 268 KB    | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvorbis-1.3.7      | 202 KB    | 7          |   8%
#
# libclang-12.0.0      | 17.8 MB   | ####8      |  48%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ########5  |  86%
# qt-main-5.15.2       | 50.0 MB   | #7         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvorbis-1.3.7      | 202 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 268 KB    | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 268 KB    | ########## | 100%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ########8  |  89%
# qt-main-5.15.2       | 50.0 MB   | #7         |  18%
#
# libclang-12.0.0      | 17.8 MB   | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.1      | 202 KB    | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 153 KB    | #          |  10%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.1      | 202 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 153 KB    | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   | #####1     |  51%
# qt-main-5.15.2       | 50.0 MB   | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# matplotlib-base-3.9. | 9.2 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libclang-12.0.0      | 17.8 MB   | #####3     |  53%
# qt-main-5.15.2       | 50.0 MB   | #9         |  19%
#
#
# matplotlib-base-3.9. | 9.2 MB    | #########7 |  98%
#
#
#
#
#
#
#
# libtiff-4.5.1        | 1.1 MB    | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   | #####5     |  55%
# qt-main-5.15.2       | 50.0 MB   | #9         |  20%
#
# libclang-12.0.0      | 17.8 MB   | #####7     |  57%
# qt-main-5.15.2       | 50.0 MB   | ##         |  21%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   | #####9     |  59%
# qt-main-5.15.2       | 50.0 MB   | ##1        |  21%
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 759 KB    | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   | ######1    |  62%
# qt-main-5.15.2       | 50.0 MB   | ##2        |  22%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 525 KB    | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   | ######4    |  65%
# qt-main-5.15.2       | 50.0 MB   | ##3        |  23%
#
# libclang-12.0.0      | 17.8 MB   | ######8    |  68%
# qt-main-5.15.2       | 50.0 MB   | ##4        |  24%
#
# libclang-12.0.0      | 17.8 MB   | #######1   |  71%
# qt-main-5.15.2       | 50.0 MB   | ##5        |  25%
#
# libclang-12.0.0      | 17.8 MB   | #######4   |  74%
# qt-main-5.15.2       | 50.0 MB   | ##6        |  26%
# qt-main-5.15.2       | 50.0 MB   | ##7        |  27%
#
# libclang-12.0.0      | 17.8 MB   | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 528 KB    | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   | ########2  |  82%
# qt-main-5.15.2       | 50.0 MB   | ##8        |  28%
# qt-main-5.15.2       | 50.0 MB   | ##9        |  30%
#
# libclang-12.0.0      | 17.8 MB   | ########5  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 303 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 303 KB    | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | ###        |  31%
#
# libclang-12.0.0      | 17.8 MB   | ########8  |  88%
# qt-main-5.15.2       | 50.0 MB   | ###2       |  32%
#
# libclang-12.0.0      | 17.8 MB   | #########2 |  93%
# qt-main-5.15.2       | 50.0 MB   | ###3       |  33%
#
#
#
# pyqt-5.15.10         | 4.2 MB    | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   | #########6 |  96%
# qt-main-5.15.2       | 50.0 MB   | ###4       |  34%
#
# libclang-12.0.0      | 17.8 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvorbis-1.3.7      | 202 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvorbis-1.3.7      | 202 KB    | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 268 KB    | ########## | 100%
#
# libclang-12.0.0      | 17.8 MB   | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | ###6       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 422 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 422 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.2          | 523 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# glib-2.84.2          | 523 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 153 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 153 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.1      | 202 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.1      | 202 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt-main-5.15.2       | 50.0 MB   | ###7       |  38%
# qt-main-5.15.2       | 50.0 MB   | ###8       |  39%
# qt-main-5.15.2       | 50.0 MB   | ###9       |  39%
# qt-main-5.15.2       | 50.0 MB   | ####       |  40%
# qt-main-5.15.2       | 50.0 MB   | ####       |  41%
# qt-main-5.15.2       | 50.0 MB   | ####1      |  41%
# qt-main-5.15.2       | 50.0 MB   | ####2      |  42%
# qt-main-5.15.2       | 50.0 MB   | ####2      |  43%
# qt-main-5.15.2       | 50.0 MB   | ####3      |  43%
#
# libclang-12.0.0      | 17.8 MB   | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | ####3      |  44%
# qt-main-5.15.2       | 50.0 MB   | ####4      |  44%
# qt-main-5.15.2       | 50.0 MB   | ####5      |  45%
# qt-main-5.15.2       | 50.0 MB   | ####5      |  46%
# qt-main-5.15.2       | 50.0 MB   | ####6      |  46%
# qt-main-5.15.2       | 50.0 MB   | ####7      |  47%
# qt-main-5.15.2       | 50.0 MB   | ####8      |  48%
# qt-main-5.15.2       | 50.0 MB   | ####9      |  49%
# qt-main-5.15.2       | 50.0 MB   | #####      |  50%
# qt-main-5.15.2       | 50.0 MB   | #####1     |  52%
# qt-main-5.15.2       | 50.0 MB   | #####3     |  53%
# qt-main-5.15.2       | 50.0 MB   | #####5     |  55%
# qt-main-5.15.2       | 50.0 MB   | #####7     |  58%
# qt-main-5.15.2       | 50.0 MB   | #####9     |  60%
# qt-main-5.15.2       | 50.0 MB   | ######1    |  62%
# qt-main-5.15.2       | 50.0 MB   | ######3    |  64%
# qt-main-5.15.2       | 50.0 MB   | ######5    |  66%
# qt-main-5.15.2       | 50.0 MB   | ######8    |  68%
# qt-main-5.15.2       | 50.0 MB   | #######    |  70%
#
#
# matplotlib-base-3.9. | 9.2 MB    | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | #######2   |  73%
# qt-main-5.15.2       | 50.0 MB   | #######4   |  75%
# qt-main-5.15.2       | 50.0 MB   | #######6   |  77%
# qt-main-5.15.2       | 50.0 MB   | #######8   |  79%
# qt-main-5.15.2       | 50.0 MB   | ########   |  80%
# qt-main-5.15.2       | 50.0 MB   | ########2  |  82%
# qt-main-5.15.2       | 50.0 MB   | ########3  |  84%
# qt-main-5.15.2       | 50.0 MB   | ########7  |  87%
# qt-main-5.15.2       | 50.0 MB   | ########9  |  89%
# qt-main-5.15.2       | 50.0 MB   | #########1 |  91%
# qt-main-5.15.2       | 50.0 MB   | #########3 |  94%
# qt-main-5.15.2       | 50.0 MB   | #########5 |  96%
# qt-main-5.15.2       | 50.0 MB   | #########7 |  98%
# qt-main-5.15.2       | 50.0 MB   | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | ########## | 100%
# qt-main-5.15.2       | 50.0 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# --- 1. Make Predictions on the Test Data ---
print("Making predictions on the test data...")
predictions_scaled = model.predict(X_test)

# --- 2. Inverse Scale the Predictions and Actuals ---
# We need to reshape the data to have 5 columns to match the scaler's input shape
# Create a dummy array with the same shape as the original data
dummy_array_pred = np.zeros((len(predictions_scaled), 5))
# Place our predictions into the first column (the 'Close' price column)
dummy_array_pred[:, 0] = predictions_scaled.ravel()
# Inverse transform the dummy array
predictions_actual = scaler.inverse_transform(dummy_array_pred)[:, 0]

# Do the same for the y_test actual values
dummy_array_actual = np.zeros((len(y_test), 5))
dummy_array_actual[:, 0] = y_test.ravel()
y_test_actual = scaler.inverse_transform(dummy_array_actual)[:, 0]
print("✅ Predictions have been converted back to actual Rupee values.")


# --- 3. Evaluate the Model's Performance ---
mae = mean_absolute_error(y_test_actual, predictions_actual)
r2 = r2_score(y_test_actual, predictions_actual)
print(f"\nModel Performance on Test Data:")
print(f"Mean Absolute Error (MAE): {mae:.2f} INR")
print(f"R-squared (R²) Score: {r2:.2f}")


# --- 4. Visualize the Results ---
plt.figure(figsize=(15, 7))
plt.plot(y_test_actual, label='Actual Price', color='blue', marker='o', linestyle='-')
plt.plot(predictions_actual, label='Predicted Price', color='red', marker='x', linestyle='--')
plt.title('Reliance Stock Price: Actual vs. Predicted (LSTM Model)')
plt.xlabel('Time (Days)')
plt.ylabel('Closing Price (INR)')
plt.legend()
plt.grid(True)
plt.savefig('lstm_prediction_vs_actual.png')
plt.show()
# Out:
# Making predictions on the test data...
# 9/9 [==============================] - 2s 24ms/step
# ✅ Predictions have been converted back to actual Rupee values.
#
# Model Performance on Test Data:
# Mean Absolute Error (MAE): 28.64 INR
# R-squared (R²) Score: 0.87

# %%
import joblib

# Save the trained LSTM model
joblib.dump(model, 'lstm_model.pkl')

# Save the scaler object
joblib.dump(scaler, 'scaler.pkl')

print("✅ Model and scaler have been saved to files.")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://03335dc6-108e-4a8b-b414-f6c4ad6b5127/assets
# INFO:tensorflow:Assets written to: ram://03335dc6-108e-4a8b-b414-f6c4ad6b5127/assets
# ✅ Model and scaler have been saved to files.
